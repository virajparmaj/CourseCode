# %% [markdown]
# # Assignment 7 - Conference

# %% [markdown]
# ### Imports

# %% [markdown]
# ## <u>Stage 1</u>: Checking Initial Model Feasibility
#
# The objective function can be something as simple as 0 now given that we are just checking if at least one feasible solution exists given all of our stiplated constraints.
#
# The data in the `band_info_cleaned.csv` file will be useful.

# %%
import pandas as pd
df=pd.read_csv('speaker_info_cleaned.csv')
df
# Out:
#     Speaker     Tier    Unavailable_Timeslots  Present_After  \
# 0         1  Keynote     4, 5, 6, 7, 8, 9, 10            6.0
# 1         2  Keynote     1, 5, 6, 7, 8, 9, 10            NaN
# 2         3  Keynote     1, 2, 3, 4, 8, 9, 10           10.0
# 3         4  Keynote     1, 2, 3, 4, 5, 9, 10            NaN
# 4         5  Keynote     4, 5, 6, 7, 8, 9, 10            NaN
# 5         6  Regular  3, 4, 5, 6, 7, 8, 9, 10            NaN
# 6         7  Regular  1, 2, 5, 6, 7, 8, 9, 10            NaN
# 7         8  Regular  1, 2, 3, 4, 7, 8, 9, 10            NaN
# 8         9  Regular  1, 2, 3, 4, 5, 6, 9, 10            NaN
# 9        10  Regular     1, 2, 3, 7, 8, 9, 10            NaN
# 10       11  Regular     4, 5, 6, 7, 8, 9, 10            NaN
# 11       12  Regular     1, 5, 6, 7, 8, 9, 10            NaN
# 12       13  Regular     1, 2, 3, 4, 8, 9, 10            NaN
# 13       14  Regular     1, 2, 3, 4, 5, 9, 10            NaN
# ...

# %% [markdown]
# #### <u>Hint #1</u>: Data Cleaning
# The data cleaning steps in Stage 1 of the Unit 4 application will be really helpful here (especially the data cleaning that we performed on `df['day_off_requested_index']`). Pay close attention to the format values in your `Unavailable_Timeslots` column take on. Ideally they should be list of integers for easier indexing in your decision variables.
#
# Check this to see what type of values they take on.

# %%
df['Unavailable_Timeslots'].loc[0]
# Out:
# '4, 5, 6, 7, 8, 9, 10'

# %% [markdown]
# ## <u>Stage 2</u>: Relaxation - Not All Speakers Have to Present, Not all Rooms/Timeslots have to be Filled

# %% [markdown]
# ## <u>Stage 3</u>: Some Speakers Get to Present More Than Once
